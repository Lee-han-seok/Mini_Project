# %% [markdown]
# # [0] 모듈 로드

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from os.path import join as opj
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pylab
plt.rcParams['figure.figsize'] = 10,10
# %matplotlib inline

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)

# import keras 
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, Activation, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras import initializers
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l1, l2, l1_l2

from sklearn.metrics import classification_report
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # [1] 데이터 로드

# %%
train = pd.read_json('./input/train.json')
train['inc_angle'] = pd.to_numeric(train['inc_angle'],errors='coerce')

# %%
test = pd.read_json('./input/test.json')
test.head()
# Out:
#          id                                             band_1  \
# 0  5941774d  [-15.863251, -15.201077, -17.887735, -19.17248...
# 1  4023181e  [-26.058969497680664, -26.058969497680664, -26...
# 2  b20200e4  [-14.14109992980957, -15.064241409301758, -17....
# 3  e7f018bb  [-12.167478, -13.706167, -16.54837, -13.572674...
# 4  4371c8c3  [-23.37459373474121, -26.02718162536621, -28.1...
#
#                                               band_2  inc_angle
# 0  [-21.629612, -21.142353, -23.908337, -28.34524...  34.966400
# 1  [-25.754207611083984, -25.754207611083984, -25...  32.615072
# 2  [-14.74563980102539, -14.590410232543945, -14....  37.505433
# 3  [-24.32222, -26.375538, -24.096739, -23.8769, ...  34.473900
# 4  [-25.72234344482422, -27.011577606201172, -23....  43.918874

# %%
train.head()
# Out:
#          id                                             band_1  \
# 0  dfd5f913  [-27.878360999999998, -27.15416, -28.668615, -...
# 1  e25388fd  [-12.242375, -14.920304999999999, -14.920363, ...
# 2  58b2aaa0  [-24.603676, -24.603714, -24.871029, -23.15277...
# 3  4cfc3a18  [-22.454607, -23.082819, -23.998013, -23.99805...
# 4  271f93f4  [-26.006956, -23.164886, -23.164886, -26.89116...
#
#                                               band_2  inc_angle  is_iceberg
# 0  [-27.154118, -29.537888, -31.0306, -32.190483,...    43.9239           0
# 1  [-31.506321, -27.984554, -26.645678, -23.76760...    38.1562           0
# 2  [-24.870956, -24.092632, -20.653963, -19.41104...    45.2859           1
# 3  [-27.889421, -27.519794, -27.165262, -29.10350...    43.8306           0
# 4  [-27.206915, -30.259186, -30.259186, -23.16495...    35.6256           0

# %%
len(train.band_1[0])
# Out:
# 5625

# %%
np.array(train.band_1[0]).shape
# Out:
# (5625,)

# %% [markdown]
# # [2] 학습을 위해 numpy 형태로 변환

# %%
X_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
X_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], X_band_2[:, :, :, np.newaxis],((X_band_1+X_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %%
X_train[0]
# Out:
# array([[[-27.87836 , -27.154118, -27.51624 ],
#         [-27.15416 , -29.537888, -28.346024],
#         [-28.668615, -31.0306  , -29.849607],
#         ...,
#         [-25.573483, -29.095308, -27.334396],
#         [-26.488674, -29.540878, -28.014776],
#         [-30.507013, -27.511766, -29.00939 ]],
#
#        [[-28.66853 , -31.030518, -29.849524],
#         [-27.8784  , -33.529335, -30.703869],
#         [-27.508776, -31.591175, -29.549976],
#         ...,
#         [-26.488632, -34.288055, -30.388344],
#         [-28.671562, -28.267496, -28.469528],
#         [-31.594166, -26.488716, -29.041441]],
#
#        [[-28.66853 , -33.52929 , -31.09891 ],
#         [-27.15416 , -37.05116 , -32.10266 ],
#         [-25.865042, -31.591175, -28.728107],
#         ...,
#         [-27.157106, -31.594084, -29.375595],
#         [-27.881393, -32.19339 , -30.037392],
#         [-32.837124, -29.54092 , -31.189022]],
#
#        ...,
#
#        [[-29.092905, -27.87895 , -28.485928],
#         [-28.669163, -27.878992, -28.274078],
#         [-30.504612, -30.00814 , -30.256376],
#         ...,
#         [-30.011005, -25.28922 , -27.650112],
#         [-25.868538, -27.512272, -26.690405],
#         [-26.489265, -28.672153, -27.58071 ]],
#
#        [[-31.591682, -29.538437, -30.56506 ],
#         [-27.878992, -29.538477, -28.708735],
#         [-28.669205, -29.09299 , -28.881098],
#         ...,
#         [-27.512272, -28.672112, -28.092192],
#         [-26.817074, -28.268087, -27.54258 ],
#         [-27.512358, -33.53296 , -30.52266 ]],
#
#        [[-29.092905, -30.008057, -29.55048 ],
#         [-26.814081, -28.669163, -27.741623],
#         [-27.15479 , -27.509365, -27.332077],
#         ...,
#         [-26.817032, -30.507519, -28.662275],
#         [-27.881983, -28.672153, -28.27707 ],
#         [-28.268127, -29.095982, -28.682055]]], dtype=float32)

# %%
test_band_1=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in test["band_1"]])
test_band_2=np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in test["band_2"]])
test = np.concatenate([test_band_1[:, :, :, np.newaxis], test_band_2[:, :, :, np.newaxis],((test_band_1+test_band_2)/2)[:, :, :, np.newaxis]], axis=-1)

# %%
test.shape
# Out:
# (8424, 75, 75, 3)

# %% [markdown]
# # [3] 빙산, 선적 시각화
# - 참고 : https://www.kaggle.com/code/muonneutrino/exploration-transforming-images-in-python

# %%
# iceberg를 가져온다.
def plotmy3d(c, name):
    data=[
        go.Surface(
            z=c
        )
    ]
    layout = go.Layout(
        title = name,
        autosize= False,
        width=700,
        height=700,
        margin=dict(
            l=65,
            r=50,
            b=65,
            t=90            
        )        
    )
    fig= go.Figure(data=data, layout=layout)
    py.iplot(fig)
plotmy3d(X_band_1[12,:,:], 'iceberg')

# %%
plotmy3d(X_band_1[14, :, :], 'Ship')

# %% [markdown]
# # [4] 모델 구축
# - VGG16 전이 학습 사용

# %%
# VGG 16을 이용해보자
from tensorflow.keras.applications import vgg16

# %%
modelVgg16 = vgg16.VGG16(include_top = False, input_shape = (75,75,3))
modelVgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 75, 75, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 75, 75, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 37, 37, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 37, 37, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 37, 37, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 18, 18, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 18, 18, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 18, 18, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 18, 18, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 9, 9, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 9, 9, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
for layer in modelVgg16.layers:
    layer.trainable = False

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, train.is_iceberg, random_state = 0)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((1203, 75, 75, 3), (401, 75, 75, 3), (1203,), (401,))

# %%
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)

# %%
model = Sequential()

model.add(modelVgg16)

model.add( BatchNormalization())

model.add(Flatten())

model.add(Dropout(0.2))
model.add(Dense(units = 64, activation = 'relu'))

model.add(Dropout(0.2))
model.add(Dense(units = 32, activation = 'relu'))

model.add(Dropout(0.2))
model.add(Dense(units = 36, activation = 'relu'))

model.add(Dense(units = 2, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['acc'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 2, 2, 512)         14714688
#
#  batch_normalization_1 (Bat  (None, 2, 2, 512)         2048
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 64)                131136
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 36)                1188
#
#  dense_7 (Dense)             (None, 2)                 74
#
# =================================================================
# Total params: 14851214 (56.65 MB)
# Trainable params: 135502 (529.30 KB)
# Non-trainable params: 14715712 (56.14 MB)
# _________________________________________________________________

# %%
# 학습
model.fit(X_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 21s 513ms/step - loss: 0.6021 - acc: 0.6525
# Epoch 2/50
# 38/38 [==============================] - 20s 516ms/step - loss: 0.4316 - acc: 0.7797
# Epoch 3/50
# 38/38 [==============================] - 19s 511ms/step - loss: 0.3779 - acc: 0.7955
# Epoch 4/50
# 38/38 [==============================] - 24s 628ms/step - loss: 0.3306 - acc: 0.8462
# Epoch 5/50
# 38/38 [==============================] - 25s 653ms/step - loss: 0.3082 - acc: 0.8603
# Epoch 6/50
# 38/38 [==============================] - 23s 599ms/step - loss: 0.2859 - acc: 0.8687
# Epoch 7/50
# 38/38 [==============================] - 22s 581ms/step - loss: 0.2636 - acc: 0.8703
# Epoch 8/50
# 38/38 [==============================] - 23s 614ms/step - loss: 0.2559 - acc: 0.8803
# Epoch 9/50
# 38/38 [==============================] - 22s 581ms/step - loss: 0.2428 - acc: 0.8886
# Epoch 10/50
# 38/38 [==============================] - 22s 582ms/step - loss: 0.2286 - acc: 0.8894
# Epoch 11/50
# 38/38 [==============================] - 22s 574ms/step - loss: 0.2085 - acc: 0.9011
# Epoch 12/50
# 38/38 [==============================] - 22s 567ms/step - loss: 0.2068 - acc: 0.9127
# Epoch 13/50
# 38/38 [==============================] - 22s 567ms/step - loss: 0.1888 - acc: 0.9119
# Epoch 14/50
# 38/38 [==============================] - 22s 568ms/step - loss: 0.1932 - acc: 0.9160
# Epoch 15/50
# 38/38 [==============================] - 22s 571ms/step - loss: 0.1830 - acc: 0.9160
# Epoch 16/50
# 38/38 [==============================] - 22s 570ms/step - loss: 0.1672 - acc: 0.9327
# Epoch 17/50
# 38/38 [==============================] - 22s 573ms/step - loss: 0.1595 - acc: 0.9352
# Epoch 18/50
# 38/38 [==============================] - 22s 570ms/step - loss: 0.1650 - acc: 0.9352
# Epoch 19/50
# 38/38 [==============================] - 22s 579ms/step - loss: 0.1531 - acc: 0.9401
# Epoch 20/50
# 38/38 [==============================] - 22s 577ms/step - loss: 0.1403 - acc: 0.9418
# Epoch 21/50
# 38/38 [==============================] - 22s 579ms/step - loss: 0.1407 - acc: 0.9443
# Epoch 22/50
# 38/38 [==============================] - 23s 605ms/step - loss: 0.1294 - acc: 0.9510
# Epoch 23/50
# 38/38 [==============================] - 23s 605ms/step - loss: 0.1147 - acc: 0.9476
# Epoch 24/50
# 38/38 [==============================] - 23s 615ms/step - loss: 0.1288 - acc: 0.9559
# Epoch 25/50
# 38/38 [==============================] - 23s 613ms/step - loss: 0.1405 - acc: 0.9385
# Epoch 26/50
# 38/38 [==============================] - 23s 608ms/step - loss: 0.1143 - acc: 0.9551
# Epoch 27/50
# 38/38 [==============================] - 23s 607ms/step - loss: 0.1272 - acc: 0.9476
# Epoch 28/50
# 38/38 [==============================] - 23s 603ms/step - loss: 0.1256 - acc: 0.9485
# Epoch 29/50
# 38/38 [==============================] - 23s 617ms/step - loss: 0.1030 - acc: 0.9534
# Epoch 30/50
# 38/38 [==============================] - 23s 604ms/step - loss: 0.1027 - acc: 0.9551
# Epoch 31/50
# 38/38 [==============================] - 23s 604ms/step - loss: 0.0975 - acc: 0.9659
# Epoch 32/50
# 38/38 [==============================] - 23s 609ms/step - loss: 0.0811 - acc: 0.9618
# Epoch 33/50
# 38/38 [==============================] - 23s 593ms/step - loss: 0.0847 - acc: 0.9643
# Epoch 34/50
# 38/38 [==============================] - 23s 614ms/step - loss: 0.0743 - acc: 0.9701
# Epoch 35/50
# 38/38 [==============================] - 24s 620ms/step - loss: 0.0933 - acc: 0.9643
# Epoch 36/50
# 38/38 [==============================] - 24s 625ms/step - loss: 0.0879 - acc: 0.9692
# Epoch 37/50
# 38/38 [==============================] - 23s 613ms/step - loss: 0.0805 - acc: 0.9717
# Epoch 38/50
# 38/38 [==============================] - 25s 661ms/step - loss: 0.0830 - acc: 0.9751
# Epoch 39/50
# 38/38 [==============================] - 24s 634ms/step - loss: 0.0981 - acc: 0.9651
# Epoch 40/50
# 38/38 [==============================] - 23s 612ms/step - loss: 0.0604 - acc: 0.9776
# Epoch 41/50
# 38/38 [==============================] - 23s 610ms/step - loss: 0.0677 - acc: 0.9751
# Epoch 42/50
# 38/38 [==============================] - 23s 599ms/step - loss: 0.0885 - acc: 0.9609
# Epoch 43/50
# 38/38 [==============================] - 23s 617ms/step - loss: 0.0834 - acc: 0.9692
# Epoch 44/50
# 38/38 [==============================] - 23s 599ms/step - loss: 0.0702 - acc: 0.9776
# Epoch 45/50
# 38/38 [==============================] - 23s 607ms/step - loss: 0.0697 - acc: 0.9734
# Epoch 46/50
# 38/38 [==============================] - 23s 616ms/step - loss: 0.0673 - acc: 0.9792
# Epoch 47/50
# 38/38 [==============================] - 23s 596ms/step - loss: 0.0774 - acc: 0.9734
# Epoch 48/50
# 38/38 [==============================] - 24s 621ms/step - loss: 0.0650 - acc: 0.9759
# Epoch 49/50
# 38/38 [==============================] - 24s 621ms/step - loss: 0.0801 - acc: 0.9734
# Epoch 50/50
# 38/38 [==============================] - 23s 615ms/step - loss: 0.0695 - acc: 0.9742

# %%
pred_train =  model.predict(X_train).argmax(axis = 1)
# Out:
# 38/38 [==============================] - 18s 480ms/step

# %%
print(classification_report(y_train.argmax(axis = 1), pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       651
#            1       1.00      1.00      1.00       552
#
#     accuracy                           1.00      1203
#    macro avg       1.00      1.00      1.00      1203
# weighted avg       1.00      1.00      1.00      1203

# %%
pred_val =  model.predict(X_val).argmax(axis = 1)
# Out:
# 13/13 [==============================] - 6s 483ms/step

# %%
print(classification_report(y_val.argmax(axis = 1), pred_val)) # 과적합 문제 발생
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.76       200
#            1       0.75      0.81      0.78       201
#
#     accuracy                           0.77       401
#    macro avg       0.77      0.77      0.77       401
# weighted avg       0.77      0.77      0.77       401

# %% [markdown]
# # [6] submission 제작

# %%
sub = pd.read_csv('./input/sample_submission.csv')
sub.head()
# Out:
#          id  is_iceberg
# 0  5941774d         0.5
# 1  4023181e         0.5
# 2  b20200e4         0.5
# 3  e7f018bb         0.5
# 4  4371c8c3         0.5

# %%
pred_test = model.predict(test)
# Out:
# 264/264 [==============================] - 162s 614ms/step

# %%
final_pred = pred_test.argmax(axis = 1)

# %%
sub['is_iceberg'] = final_pred

# %%
sub.to_csv('./input/submission.csv', index = False)

# %%
sub.head()
# Out:
#          id  is_iceberg
# 0  5941774d           1
# 1  4023181e           0
# 2  b20200e4           0
# 3  e7f018bb           1
# 4  4371c8c3           0
